# %%
import pandas as pd
import numpy as np
import pyarrow

print('numpy version:', np.__version__)
print('pandas version:', pd.__version__)
# Out:
# numpy version: 1.20.3
# pandas version: 1.3.4

# %%
path = r'C:\Stuff\School\SOFT\FHICT-S4-AI\Group\datasets\ANWB_Data_23_02_2022\trafficJams\part-01000-8db7d477-6fa7-4a12-8344-50f16ace7988-c000.snappy.parquet' 
df = pd.read_parquet(path, 'pyarrow')

# %%
df[~df['jam_delay'].isnull()].head()
# jam_delay = seconds?
# jam_distance = meters?
# Out:
#       jam_id     loaddatetimeutc       road   type  jam_delay  jam_distance  \
# 1   16418486 2022-01-04 19:29:00       N307      n      240.0         300.0
# 2   16418476 2022-01-04 19:29:00       N376      n      180.0         200.0
# 3   16418484 2022-01-04 19:29:00  Rotterdam  other      180.0         400.0
# 9   16475453 2022-01-22 05:19:00        A50      a      360.0         400.0
# 10  16415308 2022-01-02 17:04:00        A12      a      840.0        2800.0
#
#    segmentstart    segmentend  jam_codedirection  jam_afrc  ...  \
# 1     Enkhuizen      Lelystad                  0         3  ...
# 2         Assen         Emmen                  0         3  ...
# 3          None          None                  0         5  ...
# 9           Oss        Arnhem                  1         0  ...
# 10       Arnhem  Duitse grens                  1         0  ...
#
#       jam_incidenttype jam_label                             jam_location  \
# ...
