# %% [markdown]
# Reference used for this notebook [here](https://www.analyticsvidhya.com/blog/2021/07/all-you-need-to-know-about-polynomial-regression/#:~:text=Polynomial%20Regression%20is%20a%20form%20of%20Linear%20regression%20known%20as,also%20badly%20affect%20the%20performance.)

# %%
# %%html
# <style>
# table {float:left}
# img {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# img {float:left}
# </style>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
X = 6 * np.random.rand(200, 1) - 3
y = 0.8 * X**2 + 0.9*X + 2 + np.random.randn(200, 1)
#equation used -> y = 0.8x^2 + 0.9x + 2

# %%
#visualize the data
plt.plot(X, y, 'b.')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Split data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
# Apply Linear Regression model
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.20433118369515135

# %%
plt.plot(x_train, lr.predict(x_train), color="r")
plt.plot(X, y, "b.")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# Absolutely terrible.

# %% [markdown]
# ## Polynomial Linear Regression

# %%
#applying polynomial regression degree 2
poly = PolynomialFeatures(degree=2, include_bias=True)
x_train_trans = poly.fit_transform(x_train)
x_test_trans = poly.transform(x_test)
#include bias parameter
lr = LinearRegression()
lr.fit(x_train_trans, y_train)
y_pred = lr.predict(x_test_trans)
print(r2_score(y_test, y_pred))
# Out:
# 0.8513473971455011

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [[0.         0.89134188 0.82043794]]
# [1.95110237]

# %%
X_new = np.linspace(-3, 3, 200).reshape(200, 1)
X_new_poly = poly.transform(X_new)
y_new = lr.predict(X_new_poly)
plt.plot(X_new, y_new, "r-", linewidth=2, label="Predictions")
plt.plot(x_train, y_train, "b.",label='Training points')
plt.plot(x_test, y_test, "g.",label='Testing points')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# Beautifull.

# %% [markdown]
# Example of overfitted (degree 20)
# ![image.png](attachment:image.png)
